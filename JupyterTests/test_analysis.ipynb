# %%
# %matplotlib inline
### Standard imports
import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
### HEPKIT imports
import hepkit.hepData as hd
import hepkit.hepIO as hio
import hepkit.hepPlot as hp
import hepkit.hepFormat as hf
### Settings
hf.DefaultSetup()
hf.DefaultSetup()

# %%
fileLoc = '/Users/sdporzio/Data/Temp/incidentAngleTest_40-ev_100-s.root'
df = hio.OpenRoot(fileLoc,'interaction_data')

# %%
df
# Out:
#        event_number     particle_name  particle_pdg  tracks_id  parent_id  \
# entry
# 0                 2  b'opticalphoton'             0          1          0
# 1                15  b'opticalphoton'             0          1          0
# 2                20  b'opticalphoton'             0          1          0
# 3                22  b'opticalphoton'             0          1          0
# 4                24  b'opticalphoton'             0          1          0
# 5                28  b'opticalphoton'             0          1          0
# 6                29  b'opticalphoton'             0          1          0
# 7                33  b'opticalphoton'             0          1          0
# 8                37  b'opticalphoton'             0          1          0
# 9                39  b'opticalphoton'             0          1          0
#
#        xStart  yStart  zStart  tStart      xEnd      yEnd      zEnd      tEnd  \
# entry
# 0        0.15    0.15    0.15     0.0  0.065862  0.134767  0.202449  0.003346
# 1        0.15    0.15    0.15     0.0  0.118250  0.092288  0.144636  0.002204
# 2        0.15    0.15    0.15     0.0  0.118474  0.092000  0.103260  0.002698
# 3        0.15    0.15    0.15     0.0  0.140111  0.053563 -0.129748  0.009876
# 4        0.15    0.15    0.15     0.0  0.108313  0.103771  0.058967  0.003679
# 5        0.15    0.15    0.15     0.0  0.131473  0.072214 -0.034744  0.006715
# 6        0.15    0.15    0.15     0.0  0.116547  0.094428  0.123198  0.002341
# 7        0.15    0.15    0.15     0.0  0.097894  0.113652  0.159563  0.002143
# 8        0.15    0.15    0.15     0.0  0.140772  0.051801  0.141129  0.003303
# 9        0.15    0.15    0.15     0.0  0.099757  0.112020  0.140296  0.002126
#
#       preVolume postVolume  preProcess        postProcess  incidentAngle
# entry
# 0      b'World'    b'Tube'  b'Unknown'  b'Transportation'      59.686767
# 1      b'World'    b'Tube'  b'Unknown'  b'Transportation'      23.649180
# 2      b'World'    b'Tube'  b'Unknown'  b'Transportation'      41.613767
# 3      b'World'    b'Tube'  b'Unknown'  b'Transportation'      81.517233
# 4      b'World'    b'Tube'  b'Unknown'  b'Transportation'      55.739668
# 5      b'World'    b'Tube'  b'Unknown'  b'Transportation'      74.532454
# 6      b'World'    b'Tube'  b'Unknown'  b'Transportation'      29.679265
# 7      b'World'    b'Tube'  b'Unknown'  b'Transportation'      16.672511
# 8      b'World'    b'Tube'  b'Unknown'  b'Transportation'      64.539033
# 9      b'World'    b'Tube'  b'Unknown'  b'Transportation'      14.205144
